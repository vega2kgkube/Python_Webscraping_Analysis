# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
# BeautifulSoup import
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}

sid = 104
#url = f'https://news.naver.com/section/{sid}' 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)
# Out:
# https://news.naver.com/section/105

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
}

# requests 의 get() 함수 호출하기 
res=requests.get(url,headers=req_header)
print(res.status_code, res.ok)
print(type(res))
print(res)

# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
if res.ok:
    html = res.text
    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")   
    #print(soup)
    # CSS 선택자
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    '''
       <div class='sa_text'> 
          <a href="https://n.news.naver.com/mnews/article/366/0001094461" class="sa_text_title">
    '''
    a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/article'].sa_text_title")
    print(len(a_tags))
    print(type(a_tags)) #[Tag,Tag,Tag]
    # <a> 태그 리스트 순회하기
    for idx,a_tag in enumerate(a_tags,1):        
        if a_tag.text:
            title = a_tag.text.strip() # 제목
            link = a_tag['href'] # 링크
            #print(len(title))
            print(f'{idx} {title} {link}')
else:
    # 응답(response)이 Error 이면 status code 출력    
    print(f'Error Code = {res.status_code}')

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section):  #print_new(103,'생활/문화') 
    sid = section_dict[section]
    url = f'https://news.naver.com/section/{sid}'
    print(f'{url} {section} 뉴스')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
    }
    # requests 의 get() 함수 호출하기 
    res=requests.get(url,headers=req_header)
    print(res.status_code, res.ok)
    if res.ok:
        html = res.text
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")
        
    else:
        # 응답(response)이 Error 이면 status code 출력    
        print(f'Error Code = {res.status_code}')

# %%
print_news('생활/문화')
# Out:
# https://news.naver.com/section/103 생활/문화 뉴스
# 200 True
# <!DOCTYPE html>
#
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="생활/문화 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/section/103" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="날씨, 건강, 교통, 여행, 공연 등 생활/문화 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="생활/문화 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="날씨, 건강, 교통, 여행, 공연 등 생활/문화 분야 뉴스 제공" name="twitter:description"/>
# <title>생활/문화 : 네이버 뉴스</title>
# <link href="https://static-nnews.pstatic.net/css/min/20250717/news.css" rel="stylesheet"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script>
# 			var bSupportedIntersectionObserver = "IntersectionObserver" in window;
# 		</script>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "news.v3_sec";
# 			var g_default_area = "lif";
#
# 			var svr = "one-service-r-20250717-250717-162549-8dfcd689-ckgqc";
# 			var nelo = {
# 				name : "one-front",
# 				url : "https://kr-col-ext.nelo.navercorp.com/_store",
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "";
# 			var layoutName = "section_home";
# 			var layoutType = "section";
# 			var isAvailableDarkMode = false;
# 			var moduleLoadStatus = -1;
#
# 			var article = {
#
# 				officeId: "",
# 				articleId: "",
# 				sectionId : "",
# 				gdid: "",
# 				type: "",
# 				sectionInfo: {
# 					firstSection: "",
# 					secondSection: "",
# 					thirdSection: ""
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: false,
# 				isPressHome: false,
# 				name : "",
# 				category : ""
# 			};
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newslist",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false,
# 					hasSid1: true
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: true,
# 					hasSid1: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
# 					var hasSid1 = adInfo.hasSid1;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "shome";
# 					}
# 					if (hasSid1 == true) {
# 						customParam.sid1 = "103";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20250717/common.min.js"></script>
# </link></meta></head>
# <body class="n_news_mnews fs1 as_mp_layout as_section_home">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews as_type_section" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">엔터</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/" role="tab"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/section/100" role="tab"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/section/101" role="tab"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/section/102" role="tab"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="presentation">
# <a aria-selected="true" class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/section/103" role="tab"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/section/105" role="tab"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/section/104" role="tab"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111" role="tab"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home" role="tab"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver" role="tab"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh" role="tab"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver" role="tab"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.algo" href="https://media.naver.com/algorithm" role="tab"><span class="Nitem_link_menu">알고리즘 안내</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.correct" href="https://news.naver.com/ombudsman/errorArticleList" role="tab"><span class="Nitem_link_menu">정정보도 모음</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20250722160913.802";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var nilNtmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
# 	var envPhase = "production";
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# 	var gnb_item_hide_option = 128;
#
# 	var isDegradeMode = false;
# 	var isDegradeN2Mode = false;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_lnb">
# <div class="ct_lnb_inner">
# <strong class="ct_lnb_date">07.22(화)</strong>
# <ul class="ct_lnb_side">
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.allmedia" href="https://news.naver.com/main/officeList.naver">전체 언론사</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.newsstand" href="https://newsstand.naver.com/" target="_blank">뉴스스탠드</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.library" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank">라이브러리</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="ct_scroll_wrapper">
# <div class="column0">
# <div class="ct_snb">
# <h2 class="ct_snb_h2">
# <a class="ct_snb_h2_a" data-clk="lmn_lif.home" href="/section/103">생활/문화</a>
# </h2>
# <ul class="ct_snb_nav">
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="1" href="/breakingnews/section/103/241">건강정보</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="2" href="/breakingnews/section/103/239">자동차/시승기</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="3" href="/breakingnews/section/103/240">도로/교통</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="4" href="/breakingnews/section/103/237">여행/레저</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="5" href="/breakingnews/section/103/238">음식/맛집</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="6" href="/breakingnews/section/103/376">패션/뷰티</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="7" href="/breakingnews/section/103/242">공연/전시</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="8" href="/breakingnews/section/103/243">책</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="9" href="/breakingnews/section/103/244">종교</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="10" href="/breakingnews/section/103/248">날씨</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_lif.mnl" data-rank="11" href="/breakingnews/section/103/245">생활문화 일반</a>
# </li>
# </ul>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_lif.pmb" data-rank="1" href="https://media.naver.com/algorithm">
# <img alt="AI 뉴스 알고리즘 안내" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/10/184436024_banner_left.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_lif.pmb" data-rank="2" href="https://contents.premium.naver.com/">
# <img alt="프리미엄콘텐츠" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# </div>
# </div>
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" id="newsct" role="main"><div class="section_component as_section_headline _PERSIST_CONTENT" data-persist="2_sectionHeadline">
# <div class="section_article as_headline _TEMPLATE" data-template-id="SECTION_HEADLINE">
# <div class="sa_head">
# <span class="sa_head_inner">
# <a class="sa_head_link _TOGGLE" data-classvalue="is_hidden" data-clk="guide" data-target="_SECTION_HEADLINE_INFO_lpzh8" href="#">헤드라인 뉴스 <i class="sa_head_icon">안내</i></a>
# </span>
# <div class="sa_head_layer is_hidden" id="_SECTION_HEADLINE_INFO_lpzh8">
# <p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 추천되며, 기사묶음의 대표 기사는 구독 언론사 중심으로 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출됩니다.</p>
# <a class="sa_head_layer_go" href="https://media.naver.com/algorithm">알고리즘 자세히 보기</a>
# <div class="sa_head_layer_close">
# <button class="_TOGGLE" data-classvalue="is_hidden" data-target="_SECTION_HEADLINE_INFO_lpzh8" type="button">닫기</button>
# </div>
# </div>
# </div>
# <ul class="sa_list" id="_SECTION_HEADLINE_LIST_lpzh8">
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="8800006F_000000000000000001791187" data-imp-index="1" data-imp-url="https://n.news.naver.com/mnews/article/005/0001791187" href="https://n.news.naver.com/mnews/article/005/0001791187">
# <img alt="교회언론회 “특검이면 무소불위인가”…목사·교회 압수수색에 반발" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/005/2025/07/22/1791187.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="8800006F_000000000000000001791187" data-imp-index="1" data-imp-url="https://n.news.naver.com/mnews/article/005/0001791187" href="https://n.news.naver.com/mnews/article/005/0001791187">
# <strong class="sa_text_strong">교회언론회 “특검이면 무소불위인가”…목사·교회 압수수색에 반발</strong>
# </a>
# <div class="sa_text_lede">한국교회언론회(언론회·대표 임다윗 목사)가 채상병 특검의 압수수색 대상에 교회와 목회자 자택 등이 포함된 데 대해 “종교에 대한 최소한의 예의도 지키지 못했다”고 22일 강하게 비판했다. 언론회는 ‘특검(特檢)이면</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">국민일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news005,0001791187" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/005/0001791187" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507221050_00000089/section/103?oid=005&amp;aid=0001791187">
# <span class="sa_text_cluster_num">17</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="88156f73_000000000000000000544266" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/article/448/0000544266" href="https://n.news.naver.com/mnews/article/448/0000544266">
# <img alt="내일 찜통더위 속 곳곳 소나기…대구 35도·광주 34도" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/448/2025/07/22/544266.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="88156f73_000000000000000000544266" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/article/448/0000544266" href="https://n.news.naver.com/mnews/article/448/0000544266">
# <strong class="sa_text_strong">내일 찜통더위 속 곳곳 소나기…대구 35도·광주 34도</strong>
# </a>
# <div class="sa_text_lede">수요일인 23일도 푹푹 찌는 날씨가 이어지겠다. 아침 최저기온은 22∼26도, 낮 최고기온은 30∼35도로 평년[아침 21∼24도·낮 28∼32도]보다 높다. 전국 대부분 지역에 폭염특보가 발효된 가운데 밤사이 기온</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">TV조선</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news448,0000544266" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/448/0000544266" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507191010_00000040/section/103?oid=448&amp;aid=0000544266">
# <span class="sa_text_cluster_num">43</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="88000127_000000000000000013377713" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/article/003/0013377713" href="https://n.news.naver.com/mnews/article/003/0013377713">
# <img alt="BIFF 올해 아시아영화인상은?…이란 자파르 파나히 감독" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/003/2025/07/22/13377713.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="88000127_000000000000000013377713" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/article/003/0013377713" href="https://n.news.naver.com/mnews/article/003/0013377713">
# <strong class="sa_text_strong">BIFF 올해 아시아영화인상은?…이란 자파르 파나히 감독</strong>
# </a>
# <div class="sa_text_lede">부산국제영화제(BIFF)는 제30회 BIFF '올해의 아시아영화인상' 수상자로 자파르 파나히 감독을 선정했다고 22일 밝혔다. 올해의 아시아영화인상은 매해 아시아 영화 산업과 문화 발전에 있어 가장 두드러진 활동을</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴시스</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news003,0013377713" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/003/0013377713" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507220830_00000020/section/103?oid=003&amp;aid=0013377713">
# <span class="sa_text_cluster_num">9</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="88156f75_000000000000000000877159" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/article/469/0000877159" href="https://n.news.naver.com/mnews/article/469/0000877159">
# <img alt="폭우에 쓰러진 나무들, 조선왕릉도 피해… 국가유산 14건 손상" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/469/2025/07/21/877159.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="88156f75_000000000000000000877159" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/article/469/0000877159" href="https://n.news.naver.com/mnews/article/469/0000877159">
# <strong class="sa_text_strong">폭우에 쓰러진 나무들, 조선왕릉도 피해… 국가유산 14건 손상</strong>
# </a>
# <div class="sa_text_lede">16일부터 전국에 쏟아진 폭우로 인명·재산피해가 잇따르는 가운데 국가유산의 손상 사례도 속속 확인되고 있다. 서울과 경기 남양주시에 있는 유네스코 세계유산 조선왕릉 주변의 나무가 꺾였고, 울산의 옛 삼호교와 남양주시</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">한국일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news469,0000877159" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/469/0000877159" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507211310_00000017/section/103?oid=469&amp;aid=0000877159">
# <span class="sa_text_cluster_num">15</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="88000114_000000000000000011993762" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/article/056/0011993762" href="https://n.news.naver.com/mnews/article/056/0011993762">
# <img alt="대서, 폭염특보 확대·강화…내륙 강한 소나기[오후날씨 꿀팁]" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/056/2025/07/22/11993762.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# <span class="sa_thumb_play">
# <em class="blind">동영상뉴스</em>
# </span>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="88000114_000000000000000011993762" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/article/056/0011993762" href="https://n.news.naver.com/mnews/article/056/0011993762">
# <strong class="sa_text_strong">대서, 폭염특보 확대·강화…내륙 강한 소나기[오후날씨 꿀팁]</strong>
# </a>
# <div class="sa_text_lede">1년 중 가장 덥다는 절기 '대서'답게 푹푹 찌는 더위가 이어지고 있습니다. 이 시각 서울은 구름 사이로 볕이 강하게 내리쬐고 있고 체감온도는 31도를 웃돌고 있습니다. 전국 대부분 지역으로 폭염특보가 확대된 가운데</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">KBS</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news056,0011993762" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/056/0011993762" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507201720_00000001/section/103?oid=056&amp;aid=0011993762">
# <span class="sa_text_cluster_num">19</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="880000A9_000000000000000003649546" data-imp-index="6" data-imp-url="https://n.news.naver.com/mnews/article/020/0003649546" href="https://n.news.naver.com/mnews/article/020/0003649546">
# <img alt="사랑하지만 잠은 따로…美부부 3쌍 중 1쌍, ‘수면 이혼’ 중" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/020/2025/07/22/3649546.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="880000A9_000000000000000003649546" data-imp-index="6" data-imp-url="https://n.news.naver.com/mnews/article/020/0003649546" href="https://n.news.naver.com/mnews/article/020/0003649546">
# <strong class="sa_text_strong">사랑하지만 잠은 따로…美부부 3쌍 중 1쌍, ‘수면 이혼’ 중</strong>
# </a>
# <div class="sa_text_lede">미국인 부부 거의 세 쌍 중 한 쌍(31%)이 ‘수면 이혼’((sleep divorce) 중이라는 조사 결과가 나왔다. 미국 수면 의학회(The American Academy of Sleep Medicine·ASM)</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">동아일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news020,0003649546" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/020/0003649546" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507221100_00000072/section/103?oid=020&amp;aid=0003649546">
# <span class="sa_text_cluster_num">7</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="880000D8_000000000000000015521344" data-imp-index="7" data-imp-url="https://n.news.naver.com/mnews/article/001/0015521344" href="https://n.news.naver.com/mnews/article/001/0015521344">
# <img alt="관광공사, 티머니GO·카카오T와 국내여행 교통 활성화" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/001/2025/07/22/15521344.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="lif.clart" data-imp-gdid="880000D8_000000000000000015521344" data-imp-index="7" data-imp-url="https://n.news.naver.com/mnews/article/001/0015521344" href="https://n.news.naver.com/mnews/article/001/0015521344">
# <strong class="sa_text_strong">관광공사, 티머니GO·카카오T와 국내여행 교통 활성화</strong>
# </a>
# <div class="sa_text_lede">한국관광공사는 티머니모빌리티, 카카오모빌리티와 함께 지역의 관광택시와 시티투어를 모바일 앱으로 간편하게 예약·결제하는 서비스를 출시했다고 22일 밝혔다. 지난 4월 '민관 협업 관광교통 활성화' 공모로 선정한 24개</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news001,0015521344" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/001/0015521344" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507220840_00000003/section/103?oid=001&amp;aid=0015521344">
# <span class="sa_text_cluster_num">13</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="section_more _SECTION_HEADLINE_MORE_BUTTON_WRAP">
# <a class="section_more_inner _SECTION_HEADLINE_MORE_BUTTON _NLOG_IMPRESSION_TRIGGER" data-clk="clsmore" data-target="_SECTION_HEADLINE_LIST_lpzh8" href="#">헤드라인 더보기</a>
# </div>
# </div>
# <div class="section_component as_section_series _PERSIST_CONTENT" data-persist="3_sectionSeries">
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# <div class="ss_head">
# <div class="ss_head_inner">
# <a class="ss_head_link" data-clk="sert" href="https://news.naver.com/hotissue/main?sid1=163&amp;cid=2000472">
# <span class="ss_head_go">연재보기</span>
# <h2 class="ss_head_topic">책 읽는 레이디</h2>
# </a>
# </div>
# </div>
# <div class="ss_body">
# <ul class="ss_list">
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="8800006E_000000000000000000022162" data-imp-index="96r9v" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/145/0000022162?type=series&amp;cid=2000472" href="https://n.news.naver.com/mnews/hotissue/article/145/0000022162?type=series&amp;cid=2000472">
# <img alt="부동산과 로맨스가 공존한다고? &lt;아파트를 훔친 여자&gt;" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/145/2025/07/22/22162.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="8800006E_000000000000000000022162" data-imp-index="96r9v" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/145/0000022162?type=series&amp;cid=2000472" href="https://n.news.naver.com/mnews/hotissue/article/145/0000022162?type=series&amp;cid=2000472">부동산과 로맨스가 공존한다고? &lt;아파트를 훔친 여자&gt;</a>
# <div class="ss_text_lede">“10억을 벌 수 있다면, 이 결혼… 해볼 만하지 않을까요?” 강남 로또 청약을 노리는 ‘위장 부부’의 거래가 시작된다. 청약 가점을 높이기 위해 혼인신고부터 위장이혼까지 감행한 이들의 이야기. &lt;아파트를 훔친 여자</div>
# <div class="ss_text_info">
# <div class="ss_text_press">레이디경향</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news145,0000022162" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/145/0000022162" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="8800006E_000000000000000000022138" data-imp-index="acszh" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/145/0000022138?type=series&amp;cid=2000472" href="https://n.news.naver.com/mnews/hotissue/article/145/0000022138?type=series&amp;cid=2000472">
# <img alt="도시지만 생각보다 재밌어!…&lt;이다의 도시관찰일기&gt;" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/145/2025/07/15/22138.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="8800006E_000000000000000000022138" data-imp-index="acszh" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/145/0000022138?type=series&amp;cid=2000472" href="https://n.news.naver.com/mnews/hotissue/article/145/0000022138?type=series&amp;cid=2000472">도시지만 생각보다 재밌어!…&lt;이다의 도시관찰일기&gt;</a>
# <div class="ss_text_lede">요즘 세상, 솔직히 좀 피곤하다. 뉴스를 볼 때마다 세상은 더 차가워지고, 피드 속 사진들은 내 일상과는 너무나 다르다. 뭔가 열심히 해도 의미 없는 것 같고, 무기력한 기분은 계속된다. 그럴 때, 일러스트레이터 이</div>
# <div class="ss_text_info">
# <div class="ss_text_press">레이디경향</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news145,0000022138" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/145/0000022138" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="8800006E_000000000000000000022135" data-imp-index="qyf51" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/145/0000022135?type=series&amp;cid=2000472" href="https://n.news.naver.com/mnews/hotissue/article/145/0000022135?type=series&amp;cid=2000472">
# <img alt="누구나 일어날 수 있는 일…로고스 변호사들의 &lt;이혼상속 상담일지&gt;" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/145/2025/07/11/22135.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="8800006E_000000000000000000022135" data-imp-index="qyf51" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/145/0000022135?type=series&amp;cid=2000472" href="https://n.news.naver.com/mnews/hotissue/article/145/0000022135?type=series&amp;cid=2000472">누구나 일어날 수 있는 일…로고스 변호사들의 &lt;이혼상속 상담일지&gt;</a>
# <div class="ss_text_lede">“20년을 함께 살았는데 혼인신고가 없다는 이유로 재산분할이 안 된다면?” 누구에게나 일어날 수 있는 가족의 법적 갈등, 대형로펌 변호사들이 기록한 ‘현장의 이야기’가 책으로 나왔다. 유명 연예인의 이혼 소송, 수백</div>
# <div class="ss_text_info">
# <div class="ss_text_press">레이디경향</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news145,0000022135" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/145/0000022135" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="8800006E_000000000000000000022132" data-imp-index="h7aiq" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/145/0000022132?type=series&amp;cid=2000472" href="https://n.news.naver.com/mnews/hotissue/article/145/0000022132?type=series&amp;cid=2000472">
# <img alt="KTX로 두 시간 반 ‘동해’의 속살…&lt;언제라도 동해&gt;" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/145/2025/07/11/22132.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="8800006E_000000000000000000022132" data-imp-index="h7aiq" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/145/0000022132?type=series&amp;cid=2000472" href="https://n.news.naver.com/mnews/hotissue/article/145/0000022132?type=series&amp;cid=2000472">KTX로 두 시간 반 ‘동해’의 속살…&lt;언제라도 동해&gt;</a>
# <div class="ss_text_lede">빠듯한 일정의 여행에 지친 이들을 위한 새로운 제안이 도착했다. 감성 에세이 &lt;언제라도 동해&gt;는 ‘일상에서의 작은 탈출’이자 ‘삶과 여행이 맞닿는 도시’ 동해에서의 한 달 살기 기록이다. 『언제라도 여행 시리즈』의 </div>
# <div class="ss_text_info">
# <div class="ss_text_press">레이디경향</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news145,0000022132" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/145/0000022132" style="display: none;"></a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# <div class="ss_head">
# <div class="ss_head_inner">
# <a class="ss_head_link" data-clk="sert" href="https://news.naver.com/hotissue/main?sid1=163&amp;cid=2003028">
# <span class="ss_head_go">연재보기</span>
# <h2 class="ss_head_topic">오늘M7</h2>
# </a>
# </div>
# </div>
# <div class="ss_body">
# <ul class="ss_list">
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="880000E7_000000000000000006070664" data-imp-index="fcix4" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/018/0006070664?type=series&amp;cid=2003028" href="https://n.news.naver.com/mnews/hotissue/article/018/0006070664?type=series&amp;cid=2003028">
# <img alt="위기의 애플, 주가 반전을 위해 해야 할 일" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/018/2025/07/22/6070664.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="880000E7_000000000000000006070664" data-imp-index="fcix4" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/018/0006070664?type=series&amp;cid=2003028" href="https://n.news.naver.com/mnews/hotissue/article/018/0006070664?type=series&amp;cid=2003028">위기의 애플, 주가 반전을 위해 해야 할 일</a>
# <div class="ss_text_lede">21일(현지시간) S&amp;P500 지수와 나스닥 지수가 사상 최고치를 다시 썼다. 미국 대형 기술기업들의 2분기 실적 발표가 예정된 가운데 낙관론이 확산한 영향이다. S&amp;P 500 지수는 종가 기준 처음으로 6300선 </div>
# <div class="ss_text_info">
# <div class="ss_text_press">이데일리</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news018,0006070664" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/018/0006070664" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="880000E7_000000000000000006069519" data-imp-index="0dsxn" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/018/0006069519?type=series&amp;cid=2003028" href="https://n.news.naver.com/mnews/hotissue/article/018/0006069519?type=series&amp;cid=2003028">
# <img alt="테슬라, IT임원이 판매임원으로?…줄줄이 퇴사 여파" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/018/2025/07/21/6069519.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="880000E7_000000000000000006069519" data-imp-index="0dsxn" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/018/0006069519?type=series&amp;cid=2003028" href="https://n.news.naver.com/mnews/hotissue/article/018/0006069519?type=series&amp;cid=2003028">테슬라, IT임원이 판매임원으로?…줄줄이 퇴사 여파</a>
# <div class="ss_text_lede">미국 주요 빅테크사들이 이번주 분기 실적을 발표한다. 21일 증권업계에 따르면 테슬라와 구글 모회사 알파벳이 오는 23일(현지시간) 2분기(4∼6월) 실적을 내놓는다. 마이크로소프트와 페이스북 모회사 메타플랫폼은 3</div>
# <div class="ss_text_info">
# <div class="ss_text_press">이데일리</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news018,0006069519" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/018/0006069519" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="880000E7_000000000000000006068289" data-imp-index="t1g3a" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/018/0006068289?type=series&amp;cid=2003028" href="https://n.news.naver.com/mnews/hotissue/article/018/0006068289?type=series&amp;cid=2003028">
# <img alt="&quot;루시드, 너마저 로보택시&quot;…테슬라 '긴장'" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/018/2025/07/18/6068289.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="880000E7_000000000000000006068289" data-imp-index="t1g3a" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/018/0006068289?type=series&amp;cid=2003028" href="https://n.news.naver.com/mnews/hotissue/article/018/0006068289?type=series&amp;cid=2003028">"루시드, 너마저 로보택시"…테슬라 '긴장'</a>
# <div class="ss_text_lede">17일(현지시간) 뉴욕증시에서 테슬라는 소폭 하락 마감했다. 전기차 업체 루시드가 차량 공유업체 우버와 협력해 자율주행 택시 분야에 진출한다. 이달 로보택시 시범 운행을 시작한 테슬라에는 경쟁 심화가 불가피할 전망이</div>
# <div class="ss_text_info">
# <div class="ss_text_press">이데일리</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news018,0006068289" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/018/0006068289" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="880000E7_000000000000000006067503" data-imp-index="ragfw" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/018/0006067503?type=series&amp;cid=2003028" href="https://n.news.naver.com/mnews/hotissue/article/018/0006067503?type=series&amp;cid=2003028">
# <img alt="테슬라에 뿔난 뉴욕 연기금 “지분 3% 미만 주주 소송 제한 정관 삭제해야”" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/018/2025/07/17/6067503.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="lif.sera" data-imp-gdid="880000E7_000000000000000006067503" data-imp-index="ragfw" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/018/0006067503?type=series&amp;cid=2003028" href="https://n.news.naver.com/mnews/hotissue/article/018/0006067503?type=series&amp;cid=2003028">테슬라에 뿔난 뉴욕 연기금 “지분 3% 미만 주주 소송 제한 정관 삭제해야”</a>
# <div class="ss_text_lede">미국 뉴욕 연기금 감독관들이 테슬라에 주주 소송을 제한하는 정관 삭제를 요구했다. 16일(현지시간) CNBC에 따르면 최근 뉴욕주의 공적 연기금인 뉴욕주 일반퇴직기금(NYSCR, New York State Commo</div>
# <div class="ss_text_info">
# <div class="ss_text_press">이데일리</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news018,0006067503" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/018/0006067503" style="display: none;"></a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="r_group_comp ad_box _da_banner _PERSIST_HEIGHT is_border_none" data-persist="1_ad">
# <div class="ad_area _AD_WRAP" data-article="false" data-mobileonly="false" data-sync="false" data-unitid="p_news_newslist" id="nmap_c____1"></div>
# </div>
# <div class="section_latest">
# <div class="section_component as_section_article_list _PERSIST_CONTENT" data-persist="SECTION_ARTICLE_LIST">
# <div class="section_latest_article _CONTENT_LIST _PERSIST_META" data-cluid="" data-cursor="20250722135412" data-cursor-name="next" data-date="" data-has-next="true" data-nclk="airscont" data-page-no="1" data-persist="SECTION_ARTICLE_LIST_META" data-persist-meta-restore="true" data-sid="103" data-sid2="" data-template="SECTION_ARTICLE_LIST">
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST">
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"4Wp7dMFpCaRZeysQ"}}' data-gdid="8800006F_000000000000000001791283" data-imp-url="https://n.news.naver.com/mnews/article/005/0001791283" data-rank="1" href="https://n.news.naver.com/mnews/article/005/0001791283">
# <img alt="[단독] 통일교, 3남과의 ‘7000억원대’ 소송 패소…“내부분열 인정”" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/005/2025/07/22/1791283.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"4Wp7dMFpCaRZeysQ"}}' data-gdid="8800006F_000000000000000001791283" data-imp-url="https://n.news.naver.com/mnews/article/005/0001791283" data-rank="1" href="https://n.news.naver.com/mnews/article/005/0001791283">
# <strong class="sa_text_strong">[단독] 통일교, 3남과의 ‘7000억원대’ 소송 패소…“내부분열 인정”</strong>
# </a>
# <div class="sa_text_lede">한국교회에서 이단으로 규정한 세계평화통일가정연합(통일교·총재 한학자)이 고(故) 문선명과 한학재 총재의 삼남 문현진씨 측을 상대로 제기한 미국 내 자산 반환 소송에서 사실상 패소하면서 조직의 통합성과 재정 기반 모두</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">국민일보</div>
# <div class="sa_text_datetime is_recent">
# <b>13분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news005,0001791283" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/005/0001791283" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"4Wp7dMFpCaRZeysQ"}}' data-gdid="8800010E_000000000000000002503340" data-imp-url="https://n.news.naver.com/mnews/article/016/0002503340" data-rank="2" href="https://n.news.naver.com/mnews/article/016/0002503340">
# <img alt="극한 호우에 가야고분도 쓸렸다…피해 18건으로 늘어" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/016/2025/07/22/2503340.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"4Wp7dMFpCaRZeysQ"}}' data-gdid="8800010E_000000000000000002503340" data-imp-url="https://n.news.naver.com/mnews/article/016/0002503340" data-rank="2" href="https://n.news.naver.com/mnews/article/016/0002503340">
# <strong class="sa_text_strong">극한 호우에 가야고분도 쓸렸다…피해 18건으로 늘어</strong>
# </a>
# <div class="sa_text_lede">토사 일부가 유실된 경남 함안 말이산 고분군. [국가유산청] 지난 16일부터 전국 곳곳을 강타한 집중호우로 상처를 입은 국가유산 사례가 늘고 있다. 국가유산청은 이번 호우로 국가유산 피해가 발생한 사례가 총 18건으</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">헤럴드경제</div>
# <div class="sa_text_datetime is_recent">
# <b>32분전</b>
# </div>
# </div>
# ...
# <div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# <a class="col2_banner_link" data-clk="asidebanner2" href="https://media.naver.com/algorithm">
# <img alt="" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/06/183901500_banner_AI.png" height="80" style="display: none;" width="300"/>
# <div class="blind">
# <strong>알고리즘 안내</strong>
# <p></p>
# </div>
# </a>
# </div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# <div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# <a class="col2_banner_link" data-clk="asidebanner3" href="https://news.naver.com/ombudsman/guidecenter">
# <img alt="" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/06/23/195419712_banner_24hours.png" height="80" style="display: none;" width="300"/>
# <div class="blind">
# <strong>뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요</strong>
# <p></p>
# </div>
# </a>
# </div>
# </div>
# <div class="rankingnews as_type_flat mobile_hidden is_hidden _FLICKING_WRAP _OFFICE_RANKING_ALL _PERSIST_META _TEMPLATE" data-aggregation-end="" data-aggregation-start="" data-count="1" data-flicking-disable="true" data-flicking-init-tab-index="" data-flicking-nclk="true" data-grid-template-column-aside="true" data-nclk-prefix="rig" data-persist="10_officeRankingAll" data-persist-origin-content="true" data-template-id="SERVICE_INFORMATION_NEWS">
# <div class="ra_head">
# <strong class="ra_title"><em class="ra_highlight"></em> 서비스 안내</strong>
# <a class="media_more" data-clk="rig.more" href="https://news.naver.com/ombudsman"><span class="blind">더보기</span></a>
# </div>
# <div class="ra_area">
# <div class="flick" style="height:90px;">
# <div class="flick-container _FLICKING" style="height:90px; opacity:0;">
# <div class="flick-panel" data-index="0" data-subtab-count="1">
# <ul class="ranking_list _FLICKING_CONTENT" data-index="0" style="margin-top: 0;">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">고침 기사 모음</p>
# </div>
# <a class="rl_coverlink" data-clk="rig.text" href="https://news.naver.com/ombudsman/errorArticleList">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">정정·반론·추후 보도 기사 모음</p>
# </div>
# <a class="rl_coverlink" data-clk="rig.text" href="https://news.naver.com/ombudsman/revisionArticleList">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">불공정 선거 보도 기사 모음</p>
# </div>
# <a class="rl_coverlink" data-clk="rig.text" href="https://news.naver.com/ombudsman/unfairArticleList">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="outside_area _OUTSIDE_AREA">
# <div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# </div>
# <aside class="main_aside _MAIN_ASIDE">
# <div class="main_aside_inner _MAIN_ASIDE_INNER">
# <h3 class="blind">구독</h3>
# <script class="_LAZY_LOADING_IFRAME" type="x-tmpl-mustache">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%" title="구독 및 추천 채널"></iframe>
# 			</script>
# </div>
# </aside>
# </div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# <p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr/>
# <div class="u_ft _STICKY_FOOTER">
# <div class="u_ft_inner">
# <footer role="contentinfo">
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1">
# <a class="u_cra _LINK" data-clk="fot.login" data-pc-url="https://nid.naver.com/nidlogin.login" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" href="https://nid.naver.com/nidlogin.login?svctype=262144">로그인</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra _LINK" data-clk="fot.serviceall" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </span>
# </span>
# <span class="u_ftm">
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.guide" href="https://news.naver.com/ombudsman">서비스안내</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.report" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.help" href="https://help.naver.com/alias/news/news_007.naver">고객센터</a>
# </span>
# </span>
# <span class="u_charge">
# <a class="u_charge_item" data-clk="fot.editor" href="https://news.naver.com/ombudsman/edit">기사배열 책임자 : 김수향</a>
# <span class="u_charge_item">청소년 보호 책임자 : 이정규</span>
# </span>
# <span class="u_copyright">
# 					이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 <br/>이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.
# 				</span>
# <span class="u_naverlogo">
# <a class="u_naverlogo_a" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER</a>
# </span>
# </p>
# </footer>
# </div>
# </div>
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 연재는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_OS"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="" onerror="this.outerHTML='<span class=&quot;no_image&quot;></span>'">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_OS" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="napp_notify_notice">
# 	<div class="napp_notify_info_area">
# 		<strong class="napp_notify_title">네이버 앱 푸시알림이 꺼져있어요.</strong>
# 		<div class="napp_notify_desc_box">
# 			<p class="napp_notify_desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p>
# 			<p class="napp_notify_desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p>
# 		</div>
# 	</div>
# 	<div class="napp_notify_button_area">
# 		<button type="button" class="napp_notify_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}.osnotoff">닫기</button>
# 		<button type="button" class="napp_notify_btn highlight _MODAL_LAYER_POSITIVE _NAPP_NOTIFY_COMPLETE" data-clk="{{nclk}}.osnoton">네이버 앱 알림 켜기</button>
# 	</div>
# </div>
# </div>
# </script>
# <div id="_MODAL_DIALOG_WRAP" style="display: none;"></div>
# <script class="_MODAL_DIALOG_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_dialog_dimmed">
# 	<div class="nds_dialog_basic">
# 		<div class="nds_dialog_content">
# 			{{#isTextType}}
# 			<p class="nds_dialog_text">{{content.title}}</p>
# 			{{/isTextType}}
# 			{{#isTitleType}}
# 			<strong class="nds_dialog_title">
# 				<span class="nds_dialog_title_ellipsis">{{content.headTitle}}</span>
# 				{{content.title}}
# 			</strong>
# 			<p class="nds_dialog_description">{{content.description}}</p>
# 			{{/isTitleType}}
# 		</div>
# 		<div class="nds_dialog_button_area">
# 			<div class="nds_button_main_action as_layout_5_5">
# 				{{#isCancel}}
# 				<button type="button" class="nds_button_wide _MODAL_CANCEL"{{#content.clk.cancelClk}} data-clk="{{content.clk.cancelClk}}"{{/content.clk.cancelClk}}>
# 				{{content.cancelMessage}}
# 				</button>
# 				{{/isCancel}}
# 				<button type="button" class="nds_button_wide as_primary _MODAL_CONFIRM"{{#content.clk.confirmClk}} data-clk="{{content.clk.confirmClk}}"{{/content.clk.confirmClk}}>
# 				{{content.confirmMessage}}
# 				</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_TOAST" style="display: none;"></div>
# <script class="_MODAL_TOAST_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_popover_toast as_center">
# 	<div class="nds_toast_text_area">
# 		<div class="nds_toast_text_area"><span class="nds_toast_ellipsis_text"><strong>{{toastTitle}}</strong></span> {{toastMessage}}</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250717/library.min.js"></script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250717/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {};
# 		var redirectSection = {"id":"103","name":"생활"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports || service.newsType) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		var issueComponentId = $("._ISSUE_ARTICLE_INFO").attr("data-component-id");
# 		ntmOption["dimension8"] = issueComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false && $("#contents").length > 0) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("onpagehide" in window ? "pagehide" : "beforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onpagehide" in window ? "onpagehide" : "onbeforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var onUnloadEventName = "onpagehide" in window ? "onpagehide" : "onbeforeunload";
# 				var fnOnUnload = window[onUnloadEventName];
# 				window[onUnloadEventName] = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				window.ntm = window.ntm || [];
#
# 				var pageviewInfo = {
# 					event: "nLogPageViewService",
# 					nlogEvt: {
# 						page_layout: window.layoutName
# 					}
# 				};
#
# 				pageviewInfo.nLogPageviewSti = "news";
#
# 				window.ntm.push(pageviewInfo);
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": "섹션홈"
# 					},
# 					"extraInfo": {
# 						"sectionId": "103"
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
#
# 				setTimeout(function() {
# 					$("._OPACITY_FADE_TO").fadeTo(50, 1);
# 				}, 3000);
# 			});
# 		</script>
# </body>
# </html>

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':''
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

for img_url in img_urls:
    pass
    # requests 의 get(url, headers) 함수 호출하기 
        
        # binary 응답 데이터 가져오기
        
        # url에서 파일명만 추출하기
        
        # binday data를 file에 write하기

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
# Out:
# Error Code: 403

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': '',
    'X-Naver-Client-Secret': '',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 

# json() 함수로 응답 결과 가져오오기
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
